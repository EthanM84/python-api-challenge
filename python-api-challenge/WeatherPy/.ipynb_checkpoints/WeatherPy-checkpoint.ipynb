# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = f"{url}?appid={weather_api_key}&units={units}&q={city}"

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Get the JSON response
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = datetime.fromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')

        # Append the City information into city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | fort bragg
# Processing Record 3 of Set 1 | tazacorte
# Processing Record 4 of Set 1 | ha'il
# Processing Record 5 of Set 1 | port-aux-francais
# Processing Record 6 of Set 1 | mogocha
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | nieves
# Processing Record 9 of Set 1 | hawaiian paradise park
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | edinburgh of the seven seas
# Processing Record 14 of Set 1 | bilibino
# Processing Record 15 of Set 1 | yanchep
# Processing Record 16 of Set 1 | adamstown
# Processing Record 17 of Set 1 | pyapon
# Processing Record 18 of Set 1 | napier
# Processing Record 19 of Set 1 | ebon
# Processing Record 20 of Set 1 | mahibadhoo
# Processing Record 21 of Set 1 | margaret river
# Processing Record 22 of Set 1 | harper
# Processing Record 23 of Set 1 | waitangi
# Processing Record 24 of Set 1 | ha giang
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | greymouth
# Processing Record 27 of Set 1 | touros
# Processing Record 28 of Set 1 | saint-joseph
# Processing Record 29 of Set 1 | kalemie
# Processing Record 30 of Set 1 | port lincoln
# Processing Record 31 of Set 1 | invercargill
# Processing Record 32 of Set 1 | rio grande
# Processing Record 33 of Set 1 | whyalla stuart
# City not found. Skipping...
# Processing Record 34 of Set 1 | serowe
# Processing Record 35 of Set 1 | walvis bay
# Processing Record 36 of Set 1 | tiksi
# Processing Record 37 of Set 1 | orsa
# Processing Record 38 of Set 1 | waingapu
# Processing Record 39 of Set 1 | cabo san lucas
# Processing Record 40 of Set 1 | pascagoula
# Processing Record 41 of Set 1 | saint-francois
# Processing Record 42 of Set 1 | kapa'a
# Processing Record 43 of Set 1 | hamilton
# Processing Record 44 of Set 1 | ataq
# Processing Record 45 of Set 1 | siwa oasis
# Processing Record 46 of Set 1 | saipan
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | sur
# Processing Record 49 of Set 1 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 1 | ar rumaythah
# Processing Record 1 of Set 2 | gadzhiyevo
# Processing Record 2 of Set 2 | bargara
# City not found. Skipping...
# Processing Record 3 of Set 2 | minas de marcona
# Processing Record 4 of Set 2 | albany
# Processing Record 5 of Set 2 | nantucket
# Processing Record 6 of Set 2 | ad dawadimi
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | la punta
# Processing Record 9 of Set 2 | mossel bay
# Processing Record 10 of Set 2 | acarau
# Processing Record 11 of Set 2 | vavuniya
# Processing Record 12 of Set 2 | san antonio de pale
# Processing Record 13 of Set 2 | ascension
# Processing Record 14 of Set 2 | mount isa
# Processing Record 15 of Set 2 | ilulissat
# Processing Record 16 of Set 2 | itaituba
# Processing Record 17 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | inongo
# Processing Record 20 of Set 2 | iqaluit
# Processing Record 21 of Set 2 | timbuktu
# Processing Record 22 of Set 2 | portland
# Processing Record 23 of Set 2 | ulsteinvik
# Processing Record 24 of Set 2 | sitka
# Processing Record 25 of Set 2 | kargopol'
# Processing Record 26 of Set 2 | kone
# Processing Record 27 of Set 2 | amalapuram
# Processing Record 28 of Set 2 | howrah
# Processing Record 29 of Set 2 | kenai
# Processing Record 30 of Set 2 | amga
# Processing Record 31 of Set 2 | olonkinbyen
# Processing Record 32 of Set 2 | aasiaat
# Processing Record 33 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 34 of Set 2 | zuwarah
# Processing Record 35 of Set 2 | daultala
# Processing Record 36 of Set 2 | booue
# Processing Record 37 of Set 2 | klyuchi
# Processing Record 38 of Set 2 | udachny
# Processing Record 39 of Set 2 | frankenmuth
# Processing Record 40 of Set 2 | afaahiti
# Processing Record 41 of Set 2 | dalandzadgad
# Processing Record 42 of Set 2 | berezovyy
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | nantong
# Processing Record 45 of Set 2 | el grullo
# Processing Record 46 of Set 2 | manokwari
# Processing Record 47 of Set 2 | kerikeri
# Processing Record 48 of Set 2 | ribeira grande
# Processing Record 49 of Set 2 | bardai
# Processing Record 50 of Set 2 | krasnoufimsk
# Processing Record 1 of Set 3 | grytviken
# Processing Record 2 of Set 3 | magadan
# Processing Record 3 of Set 3 | crane
# Processing Record 4 of Set 3 | hammerfest
# Processing Record 5 of Set 3 | flying fish cove
# Processing Record 6 of Set 3 | port isabel
# Processing Record 7 of Set 3 | nishinoomote
# Processing Record 8 of Set 3 | wailua homesteads
# Processing Record 9 of Set 3 | kupang
# Processing Record 10 of Set 3 | santiago de cao
# Processing Record 11 of Set 3 | kempsey
# Processing Record 12 of Set 3 | dudinka
# Processing Record 13 of Set 3 | umba
# Processing Record 14 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 15 of Set 3 | papatowai
# Processing Record 16 of Set 3 | darwin
# Processing Record 17 of Set 3 | nuku'alofa
# Processing Record 18 of Set 3 | morococha
# Processing Record 19 of Set 3 | eyl
# Processing Record 20 of Set 3 | lihue
# Processing Record 21 of Set 3 | hermanus
# Processing Record 22 of Set 3 | castillos
# Processing Record 23 of Set 3 | thompson
# Processing Record 24 of Set 3 | pacific grove
# Processing Record 25 of Set 3 | gujo
# Processing Record 26 of Set 3 | kingston
# Processing Record 27 of Set 3 | nagothana
# Processing Record 28 of Set 3 | mandera
# Processing Record 29 of Set 3 | fort mcmurray
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | khalkhal
# Processing Record 32 of Set 3 | porto novo
# Processing Record 33 of Set 3 | zhigalovo
# Processing Record 34 of Set 3 | west island
# Processing Record 35 of Set 3 | hasaki
# Processing Record 36 of Set 3 | espargos
# City not found. Skipping...
# Processing Record 37 of Set 3 | hadibu
# Processing Record 38 of Set 3 | aykhal
# Processing Record 39 of Set 3 | noumea
# Processing Record 40 of Set 3 | happy valley-goose bay
# Processing Record 41 of Set 3 | buala
# Processing Record 42 of Set 3 | swakopmund
# Processing Record 43 of Set 3 | susuman
# Processing Record 44 of Set 3 | sao jose da coroa grande
# Processing Record 45 of Set 3 | sinop
# Processing Record 46 of Set 3 | jaisalmer
# Processing Record 47 of Set 3 | villa gesell
# Processing Record 48 of Set 3 | haiku-pauwela
# Processing Record 49 of Set 3 | san salvador de jujuy
# Processing Record 50 of Set 3 | pisco
# Processing Record 1 of Set 4 | lae
# Processing Record 2 of Set 4 | vorgashor
# Processing Record 3 of Set 4 | dadukou
# Processing Record 4 of Set 4 | aripuana
# Processing Record 5 of Set 4 | sampit
# Processing Record 6 of Set 4 | huarmey
# Processing Record 7 of Set 4 | mersa matruh
# Processing Record 8 of Set 4 | mwene-ditu
# Processing Record 9 of Set 4 | atafu village
# Processing Record 10 of Set 4 | flin flon
# Processing Record 11 of Set 4 | punta arenas
# Processing Record 12 of Set 4 | dabeiba
# Processing Record 13 of Set 4 | berdigestyakh
# Processing Record 14 of Set 4 | twon-brass
# Processing Record 15 of Set 4 | augusto correa
# Processing Record 16 of Set 4 | kapuskasing
# Processing Record 17 of Set 4 | vila franca do campo
# Processing Record 18 of Set 4 | ishigaki
# Processing Record 19 of Set 4 | yuzhno-kurilsk
# Processing Record 20 of Set 4 | kavieng
# Processing Record 21 of Set 4 | wynne
# Processing Record 22 of Set 4 | ust-nera
# Processing Record 23 of Set 4 | jiangkou
# Processing Record 24 of Set 4 | tabou
# Processing Record 25 of Set 4 | sinabang
# Processing Record 26 of Set 4 | vadso
# Processing Record 27 of Set 4 | port alfred
# Processing Record 28 of Set 4 | qaqortoq
# Processing Record 29 of Set 4 | opuwo
# Processing Record 30 of Set 4 | al mijlad
# Processing Record 31 of Set 4 | xinxiang
# Processing Record 32 of Set 4 | puerto aysen
# Processing Record 33 of Set 4 | tralee
# Processing Record 34 of Set 4 | talnakh
# Processing Record 35 of Set 4 | tres arroyos
# Processing Record 36 of Set 4 | metro
# Processing Record 37 of Set 4 | fes
# Processing Record 38 of Set 4 | broken hill
# Processing Record 39 of Set 4 | st. john's
# Processing Record 40 of Set 4 | gorontalo
# Processing Record 41 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 42 of Set 4 | brookings
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | nikolayevsk-on-amure
# Processing Record 45 of Set 4 | detroit lakes
# Processing Record 46 of Set 4 | karratha
# Processing Record 47 of Set 4 | iskateley
# Processing Record 48 of Set 4 | sao paulo de olivenca
# Processing Record 49 of Set 4 | saudarkrokur
# Processing Record 50 of Set 4 | nuuk
# Processing Record 1 of Set 5 | chengde
# Processing Record 2 of Set 5 | smithers
# Processing Record 3 of Set 5 | stanley
# Processing Record 4 of Set 5 | richfield
# Processing Record 5 of Set 5 | sao vicente
# Processing Record 6 of Set 5 | tromso
# Processing Record 7 of Set 5 | al mutayrifi
# Processing Record 8 of Set 5 | grand falls-windsor
# Processing Record 9 of Set 5 | braganca
# Processing Record 10 of Set 5 | vila velha
# Processing Record 11 of Set 5 | kindu
# Processing Record 12 of Set 5 | bobo-dioulasso
# Processing Record 13 of Set 5 | holualoa
# Processing Record 14 of Set 5 | ixtapa
# Processing Record 15 of Set 5 | tokar
# Processing Record 16 of Set 5 | mount pearl
# Processing Record 17 of Set 5 | itoman
# Processing Record 18 of Set 5 | kijang
# Processing Record 19 of Set 5 | kathu
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | constantia
# Processing Record 22 of Set 5 | whitehorse
# Processing Record 23 of Set 5 | robbah
# Processing Record 24 of Set 5 | chibougamau
# Processing Record 25 of Set 5 | puttalam
# Processing Record 26 of Set 5 | comodoro rivadavia
# Processing Record 27 of Set 5 | college
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | laikit, laikit ii (dimembe)
# Processing Record 30 of Set 5 | yamada
# Processing Record 31 of Set 5 | tual
# Processing Record 32 of Set 5 | lundazi
# Processing Record 33 of Set 5 | kill devil hills
# Processing Record 34 of Set 5 | cannes
# Processing Record 35 of Set 5 | miquelon
# Processing Record 36 of Set 5 | egilsstadir
# Processing Record 37 of Set 5 | molalla
# Processing Record 38 of Set 5 | binzhou
# Processing Record 39 of Set 5 | koyulhisar
# Processing Record 40 of Set 5 | avarua
# Processing Record 41 of Set 5 | kovdor
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | hilo
# Processing Record 44 of Set 5 | lebowakgomo
# Processing Record 45 of Set 5 | broome
# Processing Record 46 of Set 5 | tiberias
# Processing Record 47 of Set 5 | codrington
# Processing Record 48 of Set 5 | katsuura
# Processing Record 49 of Set 5 | thunder bay
# Processing Record 50 of Set 5 | igarka
# Processing Record 1 of Set 6 | petrinja
# Processing Record 2 of Set 6 | utrik
# Processing Record 3 of Set 6 | krasnyye barrikady
# Processing Record 4 of Set 6 | aldama
# Processing Record 5 of Set 6 | hami
# Processing Record 6 of Set 6 | sungai penuh
# Processing Record 7 of Set 6 | shortandy
# Processing Record 8 of Set 6 | charters towers
# Processing Record 9 of Set 6 | tshabong
# Processing Record 10 of Set 6 | fisterra
# Processing Record 11 of Set 6 | vanimo
# Processing Record 12 of Set 6 | saint-philippe
# Processing Record 13 of Set 6 | neiafu
# Processing Record 14 of Set 6 | kirksville
# Processing Record 15 of Set 6 | nyagan
# Processing Record 16 of Set 6 | bredasdorp
# Processing Record 17 of Set 6 | kilju
# Processing Record 18 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 19 of Set 6 | colonia
# Processing Record 20 of Set 6 | altkirch
# Processing Record 21 of Set 6 | lazaro cardenas
# Processing Record 22 of Set 6 | eastham
# Processing Record 23 of Set 6 | melong
# Processing Record 24 of Set 6 | dunedin
# Processing Record 25 of Set 6 | sigli
# Processing Record 26 of Set 6 | kinkala
# Processing Record 27 of Set 6 | port elizabeth
# Processing Record 28 of Set 6 | ancud
# Processing Record 29 of Set 6 | tukrah
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | alghero
# Processing Record 32 of Set 6 | syumsi
# Processing Record 33 of Set 6 | tura
# Processing Record 34 of Set 6 | horta
# Processing Record 35 of Set 6 | daru
# Processing Record 36 of Set 6 | nagqu
# Processing Record 37 of Set 6 | anadyr
# Processing Record 38 of Set 6 | mejit
# Processing Record 39 of Set 6 | raja
# Processing Record 40 of Set 6 | ust'-uda
# Processing Record 41 of Set 6 | bikenibeu village
# Processing Record 42 of Set 6 | uturoa
# Processing Record 43 of Set 6 | askiz
# Processing Record 44 of Set 6 | cadale
# Processing Record 45 of Set 6 | melfort
# Processing Record 46 of Set 6 | natal
# Processing Record 47 of Set 6 | tauranga
# Processing Record 48 of Set 6 | usevia
# Processing Record 49 of Set 6 | cidreira
# Processing Record 50 of Set 6 | hirara
# Processing Record 1 of Set 7 | puerto baquerizo moreno
# Processing Record 2 of Set 7 | kalmunai
# Processing Record 3 of Set 7 | vilyuchinsk
# Processing Record 4 of Set 7 | rosario oeste
# Processing Record 5 of Set 7 | medicine hat
# Processing Record 6 of Set 7 | dawei
# Processing Record 7 of Set 7 | odlabari
# Processing Record 8 of Set 7 | betio village
# Processing Record 9 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 10 of Set 7 | rosamond
# Processing Record 11 of Set 7 | mil'kovo
# Processing Record 12 of Set 7 | revda
# Processing Record 13 of Set 7 | texas city
# Processing Record 14 of Set 7 | rio gallegos
# Processing Record 15 of Set 7 | n'zeto
# Processing Record 16 of Set 7 | sofifi
# City not found. Skipping...
# Processing Record 17 of Set 7 | nikol'sk
# Processing Record 18 of Set 7 | boa vista
# Processing Record 19 of Set 7 | bulle
# Processing Record 20 of Set 7 | chany
# Processing Record 21 of Set 7 | ylitornio
# Processing Record 22 of Set 7 | samaniego
# Processing Record 23 of Set 7 | shiyan
# Processing Record 24 of Set 7 | glace bay
# Processing Record 25 of Set 7 | qiqihar
# Processing Record 26 of Set 7 | amurzet
# Processing Record 27 of Set 7 | aljezur
# Processing Record 28 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 29 of Set 7 | la passe
# Processing Record 30 of Set 7 | ribas do rio pardo
# Processing Record 31 of Set 7 | arraial do cabo
# Processing Record 32 of Set 7 | xiaolingwei
# Processing Record 33 of Set 7 | kivsharivka
# Processing Record 34 of Set 7 | kailua-kona
# Processing Record 35 of Set 7 | tangalle
# Processing Record 36 of Set 7 | waddan
# Processing Record 37 of Set 7 | chonchi
# Processing Record 38 of Set 7 | lorengau
# Processing Record 39 of Set 7 | sarpol-e zahab
# Processing Record 40 of Set 7 | ambodifotatra
# Processing Record 41 of Set 7 | along
# Processing Record 42 of Set 7 | tazovsky
# Processing Record 43 of Set 7 | shamokin
# Processing Record 44 of Set 7 | khandyga
# Processing Record 45 of Set 7 | ta`u
# Processing Record 46 of Set 7 | yerofey pavlovich
# Processing Record 47 of Set 7 | sidi ifni
# Processing Record 48 of Set 7 | mugia
# Processing Record 49 of Set 7 | petrolina
# Processing Record 50 of Set 7 | pimampiro
# Processing Record 1 of Set 8 | haizhou
# Processing Record 2 of Set 8 | toliara
# Processing Record 3 of Set 8 | abepura
# Processing Record 4 of Set 8 | kollam
# Processing Record 5 of Set 8 | coquimbo
# Processing Record 6 of Set 8 | ugoofaaru
# Processing Record 7 of Set 8 | dwarka
# Processing Record 8 of Set 8 | tevragh zeina
# City not found. Skipping...
# Processing Record 9 of Set 8 | yaren
# Processing Record 10 of Set 8 | levski
# Processing Record 11 of Set 8 | chu
# Processing Record 12 of Set 8 | alofi
# Processing Record 13 of Set 8 | dhidhdhoo
# Processing Record 14 of Set 8 | genhe
# Processing Record 15 of Set 8 | cascais
# Processing Record 16 of Set 8 | slawharad
# Processing Record 17 of Set 8 | dunstable
# Processing Record 18 of Set 8 | shangrao
# Processing Record 19 of Set 8 | mitsamiouli
# Processing Record 20 of Set 8 | narharpur
# City not found. Skipping...
# Processing Record 21 of Set 8 | antsiranana
# Processing Record 22 of Set 8 | fuglafjordur
# Processing Record 23 of Set 8 | queenstown
# Processing Record 24 of Set 8 | macia
# Processing Record 25 of Set 8 | puerto eldorado
# Processing Record 26 of Set 8 | bandon
# Processing Record 27 of Set 8 | baiao
# Processing Record 28 of Set 8 | isafjordur
# Processing Record 29 of Set 8 | bairnsdale
# Processing Record 30 of Set 8 | al bawiti
# Processing Record 31 of Set 8 | tiquipaya
# Processing Record 32 of Set 8 | forster
# Processing Record 33 of Set 8 | mount gambier
# Processing Record 34 of Set 8 | olyokminsk
# Processing Record 35 of Set 8 | kralendijk
# Processing Record 36 of Set 8 | boguchany
# Processing Record 37 of Set 8 | axim
# Processing Record 38 of Set 8 | juan griego
# Processing Record 39 of Set 8 | buturlinovka
# Processing Record 40 of Set 8 | naliya
# Processing Record 41 of Set 8 | paragominas
# Processing Record 42 of Set 8 | beira
# Processing Record 43 of Set 8 | concordia
# Processing Record 44 of Set 8 | flat river
# Processing Record 45 of Set 8 | yanbu
# Processing Record 46 of Set 8 | sanming
# Processing Record 47 of Set 8 | remire-montjoly
# Processing Record 48 of Set 8 | fortuna
# Processing Record 49 of Set 8 | severo-yeniseyskiy
# Processing Record 50 of Set 8 | brooks
# Processing Record 1 of Set 9 | tomatlan
# Processing Record 2 of Set 9 | machico
# Processing Record 3 of Set 9 | labrador city
# Processing Record 4 of Set 9 | bamboo flat
# Processing Record 5 of Set 9 | saint-pierre
# Processing Record 6 of Set 9 | al ghayzah
# Processing Record 7 of Set 9 | sisimiut
# Processing Record 8 of Set 9 | port mathurin
# Processing Record 9 of Set 9 | jiexiu
# Processing Record 10 of Set 9 | sungai raya
# Processing Record 11 of Set 9 | klaksvik
# Processing Record 12 of Set 9 | sungailiat
# Processing Record 13 of Set 9 | oroqen zizhiqi
# Processing Record 14 of Set 9 | zhaotong
# Processing Record 15 of Set 9 | kostomuksha
# Processing Record 16 of Set 9 | papao
# Processing Record 17 of Set 9 | mar del plata
# Processing Record 18 of Set 9 | saratamata
# City not found. Skipping...
# Processing Record 19 of Set 9 | bridgewater
# Processing Record 20 of Set 9 | mosjoen
# Processing Record 21 of Set 9 | newman
# Processing Record 22 of Set 9 | richards bay
# Processing Record 23 of Set 9 | quellon
# Processing Record 24 of Set 9 | palasa
# Processing Record 25 of Set 9 | san luis de la loma
# Processing Record 26 of Set 9 | rawson
# Processing Record 27 of Set 9 | hwange
# Processing Record 28 of Set 9 | isla del bosque
# Processing Record 29 of Set 9 | lagoa
# Processing Record 30 of Set 9 | hit
# Processing Record 31 of Set 9 | nova sintra
# Processing Record 32 of Set 9 | pul-e khumri
# Processing Record 33 of Set 9 | meridian
# Processing Record 34 of Set 9 | muang phonsavan
# Processing Record 35 of Set 9 | gisborne
# Processing Record 36 of Set 9 | san julian
# Processing Record 37 of Set 9 | kushiro
# Processing Record 38 of Set 9 | freeport
# Processing Record 39 of Set 9 | darzab
# Processing Record 40 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 41 of Set 9 | palikir - national government center
# Processing Record 42 of Set 9 | guerrero negro
# Processing Record 43 of Set 9 | ambon
# Processing Record 44 of Set 9 | malvan
# Processing Record 45 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 46 of Set 9 | urangan
# Processing Record 47 of Set 9 | bojonegoro
# Processing Record 48 of Set 9 | uhersky brod
# Processing Record 49 of Set 9 | kristiansund
# Processing Record 50 of Set 9 | sumenep
# Processing Record 1 of Set 10 | lelystad
# Processing Record 2 of Set 10 | port macquarie
# Processing Record 3 of Set 10 | thanh hoa
# Processing Record 4 of Set 10 | alesund
# Processing Record 5 of Set 10 | turkmenbasy
# Processing Record 6 of Set 10 | badger
# Processing Record 7 of Set 10 | tubarjal
# Processing Record 8 of Set 10 | simanggang
# Processing Record 9 of Set 10 | murmashi
# Processing Record 10 of Set 10 | brisas de zicatela
# Processing Record 11 of Set 10 | peace river
# Processing Record 12 of Set 10 | kolonia
# Processing Record 13 of Set 10 | rongelap
# Processing Record 14 of Set 10 | sesheke
# Processing Record 15 of Set 10 | rosalie
# Processing Record 16 of Set 10 | luderitz
# Processing Record 17 of Set 10 | merizo village
# Processing Record 18 of Set 10 | puerto quijarro
# Processing Record 19 of Set 10 | sainte-agathe-des-monts
# Processing Record 20 of Set 10 | santana
# Processing Record 21 of Set 10 | kerema
# Processing Record 22 of Set 10 | patong
# Processing Record 23 of Set 10 | tolanaro
# Processing Record 24 of Set 10 | saksaul'skiy
# City not found. Skipping...
# Processing Record 25 of Set 10 | alappuzha
# Processing Record 26 of Set 10 | lisala
# Processing Record 27 of Set 10 | kiunga
# Processing Record 28 of Set 10 | roma
# Processing Record 29 of Set 10 | ponta delgada
# Processing Record 30 of Set 10 | coari
# Processing Record 31 of Set 10 | george town
# Processing Record 32 of Set 10 | namibe
# Processing Record 33 of Set 10 | saldanha
# Processing Record 34 of Set 10 | poyang
# Processing Record 35 of Set 10 | ghadamis
# Processing Record 36 of Set 10 | labuan
# Processing Record 37 of Set 10 | atar
# Processing Record 38 of Set 10 | usogorsk
# Processing Record 39 of Set 10 | awjilah
# Processing Record 40 of Set 10 | barretos
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | la'ie
# Processing Record 43 of Set 10 | kogalym
# Processing Record 44 of Set 10 | manaquiri
# Processing Record 45 of Set 10 | fada
# Processing Record 46 of Set 10 | tindouf
# Processing Record 47 of Set 10 | lerwick
# Processing Record 48 of Set 10 | west milford
# Processing Record 49 of Set 10 | monywa
# Processing Record 50 of Set 10 | san juanito
# Processing Record 1 of Set 11 | ba
# City not found. Skipping...
# Processing Record 2 of Set 11 | pandan
# Processing Record 3 of Set 11 | houghton
# Processing Record 4 of Set 11 | mudgee
# Processing Record 5 of Set 11 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 11 | belyayevka
# Processing Record 7 of Set 11 | coaticook
# Processing Record 8 of Set 11 | traverse city
# Processing Record 9 of Set 11 | dryden
# Processing Record 10 of Set 11 | vernon
# Processing Record 11 of Set 11 | collie
# Processing Record 12 of Set 11 | dolinsk
# Processing Record 13 of Set 11 | smolenskoye
# Processing Record 14 of Set 11 | port de pollenca
# Processing Record 15 of Set 11 | rikaze
# Processing Record 16 of Set 11 | lake city
# Processing Record 17 of Set 11 | karaman
# Processing Record 18 of Set 11 | kittila
# Processing Record 19 of Set 11 | prainha
# Processing Record 20 of Set 11 | soio
# Processing Record 21 of Set 11 | menomonie
# Processing Record 22 of Set 11 | gornopravdinsk
# Processing Record 23 of Set 11 | mana
# Processing Record 24 of Set 11 | cobadin
# Processing Record 25 of Set 11 | hayma'
# City not found. Skipping...
# Processing Record 26 of Set 11 | sar-e pul
# Processing Record 27 of Set 11 | kudahuvadhoo
# Processing Record 28 of Set 11 | veraval
# Processing Record 29 of Set 11 | cannonvale
# Processing Record 30 of Set 11 | tucurui
# Processing Record 31 of Set 11 | port saint john's
# Processing Record 32 of Set 11 | morondava
# Processing Record 33 of Set 11 | dalnerechensk
# Processing Record 34 of Set 11 | margate
# Processing Record 35 of Set 11 | nabire
# Processing Record 36 of Set 11 | bereznik
# Processing Record 37 of Set 11 | namasuba
# Processing Record 38 of Set 11 | leninskoye
# Processing Record 39 of Set 11 | ntungamo
# Processing Record 40 of Set 11 | asau village
# City not found. Skipping...
# Processing Record 41 of Set 11 | sonsorol village
# City not found. Skipping...
# Processing Record 42 of Set 11 | novoishimskiy
# Processing Record 43 of Set 11 | shingu
# Processing Record 44 of Set 11 | el charco
# Processing Record 45 of Set 11 | shakiso
# Processing Record 46 of Set 11 | laascaanood
# Processing Record 47 of Set 11 | zhangye
# Processing Record 48 of Set 11 | turpan
# Processing Record 49 of Set 11 | port antonio
# Processing Record 50 of Set 11 | znojmo
# Processing Record 1 of Set 12 | kyzyl-mazhalyk
# Processing Record 2 of Set 12 | winburg
# Processing Record 3 of Set 12 | saint-leu
# Processing Record 4 of Set 12 | bela
# Processing Record 5 of Set 12 | sirte
# Processing Record 6 of Set 12 | emerald
# Processing Record 7 of Set 12 | argo
# Processing Record 8 of Set 12 | santa cruz
# Processing Record 9 of Set 12 | naze
# Processing Record 10 of Set 12 | fort st. john
# Processing Record 11 of Set 12 | suva
# Processing Record 12 of Set 12 | sogod
# Processing Record 13 of Set 12 | sambava
# Processing Record 14 of Set 12 | oranjemund
# Processing Record 15 of Set 12 | ca mau
# Processing Record 16 of Set 12 | sao felix do xingu
# Processing Record 17 of Set 12 | cangas del narcea
# Processing Record 18 of Set 12 | wotje
# Processing Record 19 of Set 12 | uthal
# Processing Record 20 of Set 12 | kannangad
# Processing Record 21 of Set 12 | hecun
# Processing Record 22 of Set 12 | zaozersk
# Processing Record 23 of Set 12 | laguna
# Processing Record 24 of Set 12 | itaperuna
# Processing Record 25 of Set 12 | navia
# Processing Record 26 of Set 12 | carutapera
# Processing Record 27 of Set 12 | calama
# Processing Record 28 of Set 12 | praia da vitoria
# Processing Record 29 of Set 12 | deori khas
# Processing Record 30 of Set 12 | al wajh
# Processing Record 31 of Set 12 | cihuatlan
# Processing Record 32 of Set 12 | belmonte
# Processing Record 33 of Set 12 | alness
# Processing Record 34 of Set 12 | bolu
# Processing Record 35 of Set 12 | begoro
# Processing Record 36 of Set 12 | gulf shores
# Processing Record 37 of Set 12 | labytnangi
# Processing Record 38 of Set 12 | ierapetra
# Processing Record 39 of Set 12 | sao joao da barra
# Processing Record 40 of Set 12 | antofagasta
# Processing Record 41 of Set 12 | floro
# Processing Record 42 of Set 12 | celestun
# Processing Record 43 of Set 12 | liberal
# Processing Record 44 of Set 12 | narasannapeta
# Processing Record 45 of Set 12 | san carlos del zulia
# Processing Record 46 of Set 12 | saint-denis
# Processing Record 47 of Set 12 | tharad
# Processing Record 48 of Set 12 | xiulin
# Processing Record 49 of Set 12 | cockburn town
# Processing Record 50 of Set 12 | port augusta
# Processing Record 1 of Set 13 | prince rupert
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame

# Convert the city data to a DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     puerto natales -51.7236 -72.4875     39.33        96         100
# 1         fort bragg  35.1390 -79.0060     70.83        88         100
# 2          tazacorte  28.6290 -17.9293     68.97        86           0
# 3              ha'il  27.5219  41.6907     82.42        42          20
# 4  port-aux-francais -49.3500  70.2167     43.12        95          92
#
#    Wind Speed Country                 Date
# 0        2.59      CL  2023-05-29 17:27:09
# 1        5.75      US  2023-05-29 17:27:10
# 2        6.91      ES  2023-05-29 17:27:10
# 3        6.91      SA  2023-05-29 17:26:02
# 4       28.97      TF  2023-05-29 17:27:11

# %%
# Export the City_Data to a CSV file in the output_data folder
city_data_df.to_csv("output_data/city_data.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/city_data.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           puerto natales -51.7236 -72.4875     39.33        96         100
# 1               fort bragg  35.1390 -79.0060     70.83        88         100
# 2                tazacorte  28.6290 -17.9293     68.97        86           0
# 3                    ha'il  27.5219  41.6907     82.42        42          20
# 4        port-aux-francais -49.3500  70.2167     43.12        95          92
#
#          Wind Speed Country                 Date
# City_ID
# 0              2.59      CL  2023-05-29 17:27:09
# 1              5.75      US  2023-05-29 17:27:10
# 2              6.91      ES  2023-05-29 17:27:10
# 3              6.91      SA  2023-05-29 17:26:02
# 4             28.97      TF  2023-05-29 17:27:11

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Convert Max Temperature from Fahrenheit to Celsius
city_data_df["Max Temp (C)"] = (city_data_df["Max Temp"] - 32) * 5/9

# Get the date from the DataFrame
date = city_data_df["Date"].iloc[0]

# Build scatter plot for Latitude vs. Max Temperature in Celsius
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp (C)"], edgecolor="black")

# Set the title and labels
plt.title("City Latitude vs. Max Temperature - " + date)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Celsius)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black")

# Set the title and labels
plt.title("City Latitude vs. Humidity - " + city_data_df["Date"].iloc[0])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black")

# Set the title and labels
plt.title("City Latitude vs. Cloudiness - " + city_data_df["Date"].iloc[0])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black")

# Set the title and labels
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, file_name):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line
    regress_values = x_values * slope + intercept
    
    # Create scatter plot and regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the equation of the line on the plot
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.annotate(equation, (min(x_values), min(y_values)), fontsize=12, color="red")
    
    # Set the title and labels
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    # Save the plot
    plt.savefig(file_name)
    
    # Show the plot
    plt.show()

# %%
# Filter the city data for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        fort bragg  35.1390  -79.0060     70.83        88         100
# 2         tazacorte  28.6290  -17.9293     68.97        86           0
# 3             ha'il  27.5219   41.6907     82.42        42          20
# 5           mogocha  53.7333  119.7667     40.98        95          75
# 7            nieves  15.3274  120.9485     83.71        86          96
#
#          Wind Speed Country                 Date  Max Temp (C)
# City_ID
# 1              5.75      US  2023-05-29 17:27:10     21.572222
# 2              6.91      ES  2023-05-29 17:27:10     20.538889
# 3              6.91      SA  2023-05-29 17:26:02     28.011111
# 5              2.42      RU  2023-05-29 17:27:12      4.988889
# 7              2.73      PH  2023-05-29 17:27:19     28.727778

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

# Filter the city data for Southern Hemisphere (latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           puerto natales -51.7236  -72.4875     39.33        96         100
# 4        port-aux-francais -49.3500   70.2167     43.12        95          92
# 6            blackmans bay -43.0167  147.3167     54.73        75         100
# 9             puerto ayora  -0.7393  -90.3518     87.76        93          42
# 10                 ushuaia -54.8000  -68.3000     47.86        71          40
#
#          Wind Speed Country                 Date  Max Temp (C)
# City_ID
# 0              2.59      CL  2023-05-29 17:27:09      4.072222
# 4             28.97      TF  2023-05-29 17:27:11      6.177778
# 6             10.92      AU  2023-05-29 17:27:19     12.627778
# 9              7.00      EC  2023-05-29 17:27:20     30.977778
# 10             1.14      AR  2023-05-29 17:27:20      8.811111

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, xlabel, ylabel, coordinates):
    # Convert temperature from Fahrenheit to Celsius
    y_values = (y_values - 32) * 5/9
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line
    regress_values = x_values * slope + intercept
    
    # Create the scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, color='red')
    
    # Annotate the equation of the line on the plot
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.annotate(equation, coordinates, fontsize=15, color='red')
    
    # Add titles and labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # Print the r-squared value
    print(f"The r-squared is: {round(rvalue**2, 2)}")
    
    # Show the plot
    plt.show()

# Perform linear regression on Northern Hemisphere temperature vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Temperature vs. Latitude",
                       "Latitude", "Max Temperature (°C)", (0, -30))
# Out:
# The r-squared is: 0.57

# %%
# Perform linear regression on Southern Hemisphere temperature vs latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Temperature vs. Latitude",
                       "Latitude", "Max Temperature (°C)", (-50, 40))
# Out:
# The r-squared is: 0.67

# %% [markdown]
# Based on the linear regression analysis for the Cloudiness vs. Latitude in the Northern Hemisphere, we can observe that there is no strong linear relationship between these two variables. The regression line has a small positive slope, indicating a slight increase in cloudiness as we move towards higher latitudes in the Northern Hemisphere. However, the scatter plot of the data points shows a considerable amount of dispersion, suggesting that latitude alone may not be a strong predictor of cloudiness.
#
# The low R-squared value further supports this observation, indicating that only a small proportion of the variance in cloudiness can be explained by latitude in the Northern Hemisphere. Other factors such as local weather patterns, geography, and atmospheric conditions are likely to have a more significant influence on cloudiness levels.
#
# Therefore, while there is a weak positive trend between cloudiness and latitude in the Northern Hemisphere, it is important to consider additional factors and variables to gain a more comprehensive understanding of the cloudiness patterns in this region.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere humidity vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Humidity vs. Latitude",
                       "Latitude", "Humidity (%)", (10, 40))
# Out:
# The r-squared is: 0.01

# %%
# Perform linear regression on Southern Hemisphere latitude vs humidity
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Latitude vs. Humidity",
                       "Latitude", "Humidity (%)", (-50, 20))
# Out:
# The r-squared is: 0.0

# %% [markdown]
# When comparing the linear relationships between the Southern Hemisphere and Northern Hemisphere plots, there are a few notable differences.
#
# In the Northern Hemisphere analysis, we observed a weak positive trend between latitude and the respective variable (e.g., temperature, humidity, cloudiness). The regression lines had small positive slopes, indicating a slight increase in the variable as we moved towards higher latitudes. However, the scatter plots exhibited considerable dispersion, suggesting that latitude alone may not be a strong predictor of the variable.
#
# On the other hand, in the Southern Hemisphere analysis, we might observe a different pattern. Since the Southern Hemisphere has opposite latitudinal values compared to the Northern Hemisphere, the regression lines would likely have negative slopes. This would indicate a slight decrease in the variable as we move towards higher latitudes in the Southern Hemisphere. Again, it's important to consider that other factors and variables may have a stronger influence on the observed patterns.
#
# Additionally, the R-squared values obtained from the linear regression analyses would provide insights into the strength of the relationships. A higher R-squared value suggests that a larger proportion of the variance in the variable can be explained by latitude. Conversely, a lower R-squared value implies that latitude alone may not be a robust predictor of the variable.
#
# To gain a more comprehensive understanding of the relationships in both hemispheres, it is recommended to consider additional factors such as local climate patterns, geography, seasonal variations, and atmospheric conditions. By incorporating these factors into the analysis, we can obtain a more accurate depiction of the complex interactions influencing the variables of interest in each hemisphere.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere Cloudiness vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Cloudiness vs. Latitude",
                       "Latitude", "Humidity (%)", (40, 10))
# Out:
# The r-squared is: 0.0

# %%
# Perform linear regression on Southern Hemisphere Cloudiness vs latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Cloudiness vs. Latitude",
                       "Latitude", "Humidity (%)", (-50, 20))
# Out:
# The r-squared is: 0.01

# %% [markdown]
# When comparing the Cloudiness vs. Latitude linear regression plots between the Northern Hemisphere and the Southern Hemisphere, distinct patterns may emerge.
#
# In the Northern Hemisphere, the linear regression plot for Cloudiness vs. Latitude demonstrates a scattered distribution of data points. The regression line has a slight positive slope, indicating a modest increase in cloudiness as we move towards higher latitudes. However, the dispersion of the data points suggests that latitude alone is not a strong predictor of cloudiness. Other factors, such as local weather systems, terrain features, and atmospheric conditions, likely play significant roles in determining cloudiness levels in the Northern Hemisphere.
#
# In contrast, the Southern Hemisphere's linear regression plot for Cloudiness vs. Latitude might exhibit different characteristics. Due to the reversed latitudinal values, the regression line would likely have a negative slope, suggesting a slight decrease in cloudiness as we move towards higher latitudes in the Southern Hemisphere. Similar to the Northern Hemisphere, the scatter of data points implies that latitude alone might not be a reliable indicator of cloudiness. Factors unique to the Southern Hemisphere, such as prevailing wind patterns and oceanic influences, may exert more substantial control over cloudiness patterns.
#
# Comparing the R-squared values between the two regression analyses can provide additional insights. A higher R-squared value indicates that a larger proportion of the cloudiness variance can be explained by latitude. Conversely, a lower R-squared value suggests that latitude alone may not be a robust predictor of cloudiness in either hemisphere.
#
# To gain a comprehensive understanding of cloudiness patterns in both hemispheres, it is crucial to consider additional factors. Local climate phenomena, geographical features, seasonal variations, and prevailing wind directions are among the variables that might contribute to cloudiness variations. By incorporating these factors into the analysis, we can obtain a more accurate depiction of the complex dynamics influencing cloudiness in the Northern and Southern Hemispheres.
#
# In summary, while the linear regression plots for Cloudiness vs. Latitude in the Northern and Southern Hemispheres may exhibit different slopes, both plots indicate that latitude alone is not a strong predictor of cloudiness. Understanding the interplay between latitude and various regional factors is essential for unraveling the intricate relationships and obtaining a more comprehensive understanding of cloudiness patterns in each hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere wind speed vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Wind Speed vs. Latitude",
                       "Latitude", "Wind Speed (mph)", (40, 10))
# Out:
# The r-squared is: 0.0

# %%
# Perform linear regression on Southern Hemisphere wind speed vs latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Wind Speed vs. Latitude",
                       "Latitude", "Wind Speed (mph)", (-50, 20))
# Out:
# The r-squared is: 0.04

# %% [markdown]
# When examining the Wind Speed vs. Latitude linear regression plots between the Northern Hemisphere and the Southern Hemisphere, distinctive characteristics and trends can emerge.
#
# In the Northern Hemisphere, the linear regression plot for Wind Speed vs. Latitude reveals a scattered distribution of data points. The regression line generally shows a slight increase in wind speed as we move towards higher latitudes, indicating a potential correlation between latitude and wind speed. However, the dispersion of the data points suggests that latitude alone is not a strong predictor of wind speed. Other factors, such as local topography, temperature gradients, and atmospheric pressure systems, significantly influence wind patterns in the Northern Hemisphere.
#
# In the Southern Hemisphere, the linear regression plot might present a different pattern. Due to the reversed latitudinal values, the regression line would likely have a negative slope, indicating a potential decrease in wind speed as we move towards higher latitudes in the Southern Hemisphere. Similarly, latitude alone may not be a robust predictor of wind speed, and factors specific to the Southern Hemisphere, such as ocean currents and wind circulation patterns, may have a more substantial influence.
#
# Comparing the R-squared values between the two regression analyses can provide further insights. A higher R-squared value signifies a greater proportion of the wind speed variance that can be explained by latitude. Conversely, a lower R-squared value implies that latitude alone may not be a strong predictor of wind speed in either hemisphere.
#
# To comprehensively understand wind speed patterns in both hemispheres, it is crucial to consider additional variables. Factors such as local topography, proximity to bodies of water, atmospheric pressure gradients, and large-scale weather systems play significant roles in shaping wind patterns. Incorporating these variables into the analysis can provide a more accurate understanding of the complex dynamics influencing wind speed in the Northern and Southern Hemispheres.
#
# In summary, the Wind Speed vs. Latitude linear regression plots demonstrate some trends between wind speed and latitude in both hemispheres. However, latitude alone does not provide a complete explanation for wind speed variations. Understanding the interactions between latitude and other atmospheric and geographical factors is essential for gaining a comprehensive understanding of wind speed patterns in each hemisphere.
