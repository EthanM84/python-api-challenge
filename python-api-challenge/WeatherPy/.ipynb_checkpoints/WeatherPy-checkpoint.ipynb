# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from datetime import datetime

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"
units = "imperial"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = f"{url}?appid={weather_api_key}&units={units}&q={city}"

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Get the JSON response
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = datetime.fromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')

        # Append the City information into city_data list
        city_data.append({
            "City": city,
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | invercargill
# Processing Record 2 of Set 1 | yellowknife
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | adamstown
# Processing Record 6 of Set 1 | galle
# Processing Record 7 of Set 1 | waitangi
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | midvagur
# Processing Record 10 of Set 1 | kill devil hills
# Processing Record 11 of Set 1 | tura
# Processing Record 12 of Set 1 | atafu village
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | kongsvinger
# Processing Record 15 of Set 1 | labytnangi
# Processing Record 16 of Set 1 | minas de marcona
# Processing Record 17 of Set 1 | fortuna
# Processing Record 18 of Set 1 | beroroha
# Processing Record 19 of Set 1 | knoxville
# Processing Record 20 of Set 1 | villa ocampo
# Processing Record 21 of Set 1 | ilulissat
# Processing Record 22 of Set 1 | anadyr
# Processing Record 23 of Set 1 | bayanhongor
# Processing Record 24 of Set 1 | callao
# Processing Record 25 of Set 1 | morondava
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | taourirt
# Processing Record 28 of Set 1 | steinbach
# Processing Record 29 of Set 1 | haiku-pauwela
# Processing Record 30 of Set 1 | barra de santo antonio
# Processing Record 31 of Set 1 | west island
# Processing Record 32 of Set 1 | chonchi
# Processing Record 33 of Set 1 | keflavik
# Processing Record 34 of Set 1 | udachny
# Processing Record 35 of Set 1 | zagora
# Processing Record 36 of Set 1 | ath thawrah
# Processing Record 37 of Set 1 | sodankyla
# Processing Record 38 of Set 1 | kristiansund
# Processing Record 39 of Set 1 | vila velha
# Processing Record 40 of Set 1 | port elizabeth
# Processing Record 41 of Set 1 | tulun
# Processing Record 42 of Set 1 | palmer
# Processing Record 43 of Set 1 | itambacuri
# Processing Record 44 of Set 1 | lorengau
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | stanley
# Processing Record 47 of Set 1 | iqaluit
# Processing Record 48 of Set 1 | enewetak
# Processing Record 49 of Set 1 | ma'rib
# Processing Record 50 of Set 1 | broken hill
# Processing Record 1 of Set 2 | canto do buriti
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | anna regina
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | isafjordur
# Processing Record 6 of Set 2 | cestos city
# Processing Record 7 of Set 2 | susuman
# Processing Record 8 of Set 2 | edinburgh of the seven seas
# Processing Record 9 of Set 2 | iskateley
# Processing Record 10 of Set 2 | ushuaia
# Processing Record 11 of Set 2 | buritizeiro
# Processing Record 12 of Set 2 | bonthe
# Processing Record 13 of Set 2 | genhe
# Processing Record 14 of Set 2 | la passe
# Processing Record 15 of Set 2 | namibe
# Processing Record 16 of Set 2 | phan rang-thap cham
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | cabo san lucas
# Processing Record 19 of Set 2 | dudinka
# Processing Record 20 of Set 2 | sao felix do xingu
# Processing Record 21 of Set 2 | kingston
# Processing Record 22 of Set 2 | weno
# Processing Record 23 of Set 2 | howrah
# Processing Record 24 of Set 2 | buka
# Processing Record 25 of Set 2 | bloemfontein
# Processing Record 26 of Set 2 | suva
# Processing Record 27 of Set 2 | comber
# Processing Record 28 of Set 2 | blackmans bay
# Processing Record 29 of Set 2 | mahibadhoo
# Processing Record 30 of Set 2 | laguna
# Processing Record 31 of Set 2 | mohammedia
# Processing Record 32 of Set 2 | sao jose da coroa grande
# Processing Record 33 of Set 2 | bodo
# Processing Record 34 of Set 2 | selfoss
# Processing Record 35 of Set 2 | hammerfest
# Processing Record 36 of Set 2 | thompson
# Processing Record 37 of Set 2 | pisco
# Processing Record 38 of Set 2 | nar'yan-mar
# Processing Record 39 of Set 2 | shingu
# Processing Record 40 of Set 2 | moree
# Processing Record 41 of Set 2 | arraial do cabo
# Processing Record 42 of Set 2 | nema
# Processing Record 43 of Set 2 | newman
# Processing Record 44 of Set 2 | jolalpan
# Processing Record 45 of Set 2 | salalah
# Processing Record 46 of Set 2 | dunedin
# Processing Record 47 of Set 2 | gaspe
# Processing Record 48 of Set 2 | carnarvon
# Processing Record 49 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 50 of Set 2 | lihue
# Processing Record 1 of Set 3 | 'ain deheb
# Processing Record 2 of Set 3 | long beach
# Processing Record 3 of Set 3 | konarka
# Processing Record 4 of Set 3 | sealy
# Processing Record 5 of Set 3 | klyuchi
# Processing Record 6 of Set 3 | gwadar
# Processing Record 7 of Set 3 | san patricio
# Processing Record 8 of Set 3 | utrik
# Processing Record 9 of Set 3 | emerald
# Processing Record 10 of Set 3 | nizao
# Processing Record 11 of Set 3 | mount isa
# Processing Record 12 of Set 3 | estevan
# Processing Record 13 of Set 3 | margaret river
# Processing Record 14 of Set 3 | luanda
# Processing Record 15 of Set 3 | sirte
# Processing Record 16 of Set 3 | vilyuchinsk
# Processing Record 17 of Set 3 | tsiombe
# Processing Record 18 of Set 3 | tamandare
# Processing Record 19 of Set 3 | taiohae
# City not found. Skipping...
# Processing Record 20 of Set 3 | riyadh
# Processing Record 21 of Set 3 | martuk
# Processing Record 22 of Set 3 | mansa
# Processing Record 23 of Set 3 | mahina
# Processing Record 24 of Set 3 | ettenheim
# Processing Record 25 of Set 3 | hadibu
# Processing Record 26 of Set 3 | letlhakeng
# Processing Record 27 of Set 3 | guiuan
# Processing Record 28 of Set 3 | badger
# Processing Record 29 of Set 3 | wailua homesteads
# Processing Record 30 of Set 3 | pokhara
# Processing Record 31 of Set 3 | soe
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | kashgar
# Processing Record 34 of Set 3 | bethel
# Processing Record 35 of Set 3 | tiksi
# Processing Record 36 of Set 3 | al hazm
# Processing Record 37 of Set 3 | howard springs
# Processing Record 38 of Set 3 | lodja
# Processing Record 39 of Set 3 | ola
# Processing Record 40 of Set 3 | kodiak
# Processing Record 41 of Set 3 | gotsucho
# Processing Record 42 of Set 3 | tremp
# Processing Record 43 of Set 3 | olonkinbyen
# Processing Record 44 of Set 3 | new norfolk
# Processing Record 45 of Set 3 | pingliang
# Processing Record 46 of Set 3 | norrtalje
# Processing Record 47 of Set 3 | kirensk
# Processing Record 48 of Set 3 | georgetown
# Processing Record 49 of Set 3 | buon ma thuot
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | ust-nera
# Processing Record 2 of Set 4 | jiwani
# Processing Record 3 of Set 4 | mirny
# Processing Record 4 of Set 4 | tazovsky
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | labrador city
# Processing Record 7 of Set 4 | prado
# Processing Record 8 of Set 4 | kialla
# Processing Record 9 of Set 4 | caleta de carquin
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | afaahiti
# Processing Record 12 of Set 4 | uturoa
# Processing Record 13 of Set 4 | am timan
# Processing Record 14 of Set 4 | bodaybo
# Processing Record 15 of Set 4 | 'afrin
# City not found. Skipping...
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | talnakh
# Processing Record 18 of Set 4 | mata-utu
# Processing Record 19 of Set 4 | al kharj
# Processing Record 20 of Set 4 | tacna
# Processing Record 21 of Set 4 | cooma
# Processing Record 22 of Set 4 | praia da vitoria
# Processing Record 23 of Set 4 | quellon
# Processing Record 24 of Set 4 | novo aripuana
# Processing Record 25 of Set 4 | college
# Processing Record 26 of Set 4 | ciudad lazaro cardenas
# Processing Record 27 of Set 4 | upata
# Processing Record 28 of Set 4 | kresttsy
# Processing Record 29 of Set 4 | pieksamaki
# Processing Record 30 of Set 4 | banfora
# Processing Record 31 of Set 4 | salida
# Processing Record 32 of Set 4 | sinjai
# Processing Record 33 of Set 4 | saint-francois
# Processing Record 34 of Set 4 | boende
# Processing Record 35 of Set 4 | wynyard
# Processing Record 36 of Set 4 | aykhal
# Processing Record 37 of Set 4 | tabou
# Processing Record 38 of Set 4 | mikuni
# Processing Record 39 of Set 4 | marica
# Processing Record 40 of Set 4 | puerto san carlos
# City not found. Skipping...
# Processing Record 41 of Set 4 | torquay
# Processing Record 42 of Set 4 | praya
# Processing Record 43 of Set 4 | hawaiian paradise park
# Processing Record 44 of Set 4 | puerto natales
# Processing Record 45 of Set 4 | abqaiq
# Processing Record 46 of Set 4 | guangyuan
# Processing Record 47 of Set 4 | lieksa
# Processing Record 48 of Set 4 | bilibino
# Processing Record 49 of Set 4 | laojunmiao
# Processing Record 50 of Set 4 | cargados carajos
# City not found. Skipping...
# Processing Record 1 of Set 5 | wolbrom
# Processing Record 2 of Set 5 | fort bragg
# Processing Record 3 of Set 5 | toliara
# Processing Record 4 of Set 5 | atherton
# Processing Record 5 of Set 5 | pangai
# Processing Record 6 of Set 5 | pudasjarvi
# Processing Record 7 of Set 5 | san fernando
# Processing Record 8 of Set 5 | remire-montjoly
# Processing Record 9 of Set 5 | puerto baquerizo moreno
# Processing Record 10 of Set 5 | horta
# Processing Record 11 of Set 5 | linhares
# Processing Record 12 of Set 5 | williams lake
# Processing Record 13 of Set 5 | raja
# Processing Record 14 of Set 5 | zaozersk
# Processing Record 15 of Set 5 | kulhudhuffushi
# Processing Record 16 of Set 5 | pak phanang
# Processing Record 17 of Set 5 | amga
# Processing Record 18 of Set 5 | qaqortoq
# Processing Record 19 of Set 5 | port shepstone
# Processing Record 20 of Set 5 | cabanas
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | nova xavantina
# Processing Record 23 of Set 5 | fale old settlement
# Processing Record 24 of Set 5 | presidente epitacio
# Processing Record 25 of Set 5 | port mathurin
# Processing Record 26 of Set 5 | tommot
# Processing Record 27 of Set 5 | usinsk
# Processing Record 28 of Set 5 | holualoa
# Processing Record 29 of Set 5 | primorskiy
# Processing Record 30 of Set 5 | karmala
# Processing Record 31 of Set 5 | bel ombre
# Processing Record 32 of Set 5 | pierre
# Processing Record 33 of Set 5 | hamilton
# Processing Record 34 of Set 5 | balqash
# Processing Record 35 of Set 5 | papatowai
# Processing Record 36 of Set 5 | avarua
# Processing Record 37 of Set 5 | horncastle
# Processing Record 38 of Set 5 | mollendo
# Processing Record 39 of Set 5 | kalispell
# Processing Record 40 of Set 5 | qamdo
# Processing Record 41 of Set 5 | el galpon
# Processing Record 42 of Set 5 | seme
# Processing Record 43 of Set 5 | dhidhdhoo
# Processing Record 44 of Set 5 | nuuk
# Processing Record 45 of Set 5 | alofi
# Processing Record 46 of Set 5 | korla
# Processing Record 47 of Set 5 | riohacha
# Processing Record 48 of Set 5 | tangalle
# Processing Record 49 of Set 5 | egilsstadir
# Processing Record 50 of Set 5 | sao gabriel
# Processing Record 1 of Set 6 | trincomalee
# Processing Record 2 of Set 6 | villa union
# Processing Record 3 of Set 6 | avsallar
# Processing Record 4 of Set 6 | beledweyne
# Processing Record 5 of Set 6 | cidreira
# Processing Record 6 of Set 6 | saldanha
# Processing Record 7 of Set 6 | mankapur
# Processing Record 8 of Set 6 | muisne
# Processing Record 9 of Set 6 | tranqueras
# Processing Record 10 of Set 6 | key west
# Processing Record 11 of Set 6 | vernon
# Processing Record 12 of Set 6 | adam
# Processing Record 13 of Set 6 | isle of lewis
# City not found. Skipping...
# Processing Record 14 of Set 6 | hithadhoo
# Processing Record 15 of Set 6 | novodvinsk
# Processing Record 16 of Set 6 | mahdia
# Processing Record 17 of Set 6 | rishikesh
# Processing Record 18 of Set 6 | saint croix
# Processing Record 19 of Set 6 | papao
# Processing Record 20 of Set 6 | ghat
# Processing Record 21 of Set 6 | lebu
# Processing Record 22 of Set 6 | las heras
# Processing Record 23 of Set 6 | naze
# Processing Record 24 of Set 6 | santa terezinha
# Processing Record 25 of Set 6 | jejuri
# Processing Record 26 of Set 6 | happy valley-goose bay
# Processing Record 27 of Set 6 | ribeira grande
# Processing Record 28 of Set 6 | luderitz
# Processing Record 29 of Set 6 | tomakivka
# Processing Record 30 of Set 6 | stephenville
# Processing Record 31 of Set 6 | fort st. john
# Processing Record 32 of Set 6 | yerkoy
# Processing Record 33 of Set 6 | todos santos
# Processing Record 34 of Set 6 | zouerate
# Processing Record 35 of Set 6 | alaghsas
# Processing Record 36 of Set 6 | yanchep
# Processing Record 37 of Set 6 | pacific grove
# Processing Record 38 of Set 6 | ambon
# Processing Record 39 of Set 6 | magadan
# Processing Record 40 of Set 6 | ghazni
# Processing Record 41 of Set 6 | mildura
# Processing Record 42 of Set 6 | carauari
# Processing Record 43 of Set 6 | dapa
# Processing Record 44 of Set 6 | merizo village
# Processing Record 45 of Set 6 | lijiang
# Processing Record 46 of Set 6 | motygino
# Processing Record 47 of Set 6 | juneau
# Processing Record 48 of Set 6 | kuta
# Processing Record 49 of Set 6 | kavieng
# Processing Record 50 of Set 6 | ocean shores
# Processing Record 1 of Set 7 | vrangel'
# Processing Record 2 of Set 7 | fedorovka
# Processing Record 3 of Set 7 | az zawr
# Processing Record 4 of Set 7 | kapa'a
# Processing Record 5 of Set 7 | la sarre
# Processing Record 6 of Set 7 | flying fish cove
# Processing Record 7 of Set 7 | pestravka
# Processing Record 8 of Set 7 | miri
# Processing Record 9 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 10 of Set 7 | bremervorde
# Processing Record 11 of Set 7 | chibougamau
# Processing Record 12 of Set 7 | sadjoavato
# City not found. Skipping...
# Processing Record 13 of Set 7 | saipan
# Processing Record 14 of Set 7 | xuddur
# Processing Record 15 of Set 7 | antofagasta
# Processing Record 16 of Set 7 | luga
# Processing Record 17 of Set 7 | ormara
# Processing Record 18 of Set 7 | hofheim in unterfranken
# Processing Record 19 of Set 7 | carahue
# Processing Record 20 of Set 7 | santarem
# Processing Record 21 of Set 7 | tegueste
# Processing Record 22 of Set 7 | macas
# Processing Record 23 of Set 7 | shetpe
# Processing Record 24 of Set 7 | erechim
# Processing Record 25 of Set 7 | sivagiri
# Processing Record 26 of Set 7 | port-vila
# Processing Record 27 of Set 7 | letlhakane
# Processing Record 28 of Set 7 | mbanza-ngungu
# Processing Record 29 of Set 7 | coronel suarez
# Processing Record 30 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 31 of Set 7 | limulunga
# Processing Record 32 of Set 7 | sorong
# Processing Record 33 of Set 7 | polyarnyy
# Processing Record 34 of Set 7 | queenstown
# Processing Record 35 of Set 7 | xingtai
# Processing Record 36 of Set 7 | vadso
# Processing Record 37 of Set 7 | sinsang-ni
# Processing Record 38 of Set 7 | kerikeri
# Processing Record 39 of Set 7 | mana
# Processing Record 40 of Set 7 | bredasdorp
# Processing Record 41 of Set 7 | mohr
# Processing Record 42 of Set 7 | nouadhibou
# Processing Record 43 of Set 7 | port lincoln
# Processing Record 44 of Set 7 | powell river
# Processing Record 45 of Set 7 | toga village
# City not found. Skipping...
# Processing Record 46 of Set 7 | bikenibeu village
# Processing Record 47 of Set 7 | alghero
# Processing Record 48 of Set 7 | tranovaho
# City not found. Skipping...
# Processing Record 49 of Set 7 | clevelandia
# Processing Record 50 of Set 7 | kargil
# Processing Record 1 of Set 8 | lebyazh'ye
# Processing Record 2 of Set 8 | shizunai-furukawacho
# Processing Record 3 of Set 8 | port isabel
# Processing Record 4 of Set 8 | cuatro cienegas de carranza
# Processing Record 5 of Set 8 | tolanaro
# Processing Record 6 of Set 8 | lauro de freitas
# Processing Record 7 of Set 8 | el granada
# Processing Record 8 of Set 8 | devinuwara
# City not found. Skipping...
# Processing Record 9 of Set 8 | alakurtti
# Processing Record 10 of Set 8 | guerrero negro
# Processing Record 11 of Set 8 | tan-tan
# Processing Record 12 of Set 8 | lisakovsk
# Processing Record 13 of Set 8 | udaipur
# Processing Record 14 of Set 8 | oriximina
# Processing Record 15 of Set 8 | forster
# Processing Record 16 of Set 8 | olgii
# City not found. Skipping...
# Processing Record 17 of Set 8 | broome
# Processing Record 18 of Set 8 | kailua-kona
# Processing Record 19 of Set 8 | tamanrasset
# Processing Record 20 of Set 8 | okha
# Processing Record 21 of Set 8 | kangding
# Processing Record 22 of Set 8 | flin flon
# Processing Record 23 of Set 8 | ishigaki
# Processing Record 24 of Set 8 | puerto san jose
# Processing Record 25 of Set 8 | lautoka
# Processing Record 26 of Set 8 | mrakovo
# Processing Record 27 of Set 8 | santa marta
# Processing Record 28 of Set 8 | calvinia
# Processing Record 29 of Set 8 | abu 'arish
# City not found. Skipping...
# Processing Record 30 of Set 8 | alice springs
# Processing Record 31 of Set 8 | touros
# Processing Record 32 of Set 8 | san jose village
# City not found. Skipping...
# Processing Record 33 of Set 8 | svetlyy
# Processing Record 34 of Set 8 | atasu
# Processing Record 35 of Set 8 | luwuk
# Processing Record 36 of Set 8 | canico
# Processing Record 37 of Set 8 | ratnagiri
# Processing Record 38 of Set 8 | mbaiki
# Processing Record 39 of Set 8 | aasiaat
# Processing Record 40 of Set 8 | vavuniya
# Processing Record 41 of Set 8 | stawell
# Processing Record 42 of Set 8 | puerto deseado
# Processing Record 43 of Set 8 | ulladulla
# Processing Record 44 of Set 8 | sant antoni de portmany
# Processing Record 45 of Set 8 | nova sintra
# Processing Record 46 of Set 8 | qandala
# Processing Record 47 of Set 8 | vilyuysk
# Processing Record 48 of Set 8 | port douglas
# Processing Record 49 of Set 8 | namtsy
# Processing Record 50 of Set 8 | agnibilekrou
# Processing Record 1 of Set 9 | tofol
# Processing Record 2 of Set 9 | jaithari
# Processing Record 3 of Set 9 | dawei
# Processing Record 4 of Set 9 | constantia
# Processing Record 5 of Set 9 | luang namtha
# Processing Record 6 of Set 9 | sainyabuli
# Processing Record 7 of Set 9 | isla mujeres
# Processing Record 8 of Set 9 | al jawf
# Processing Record 9 of Set 9 | sao vicente
# Processing Record 10 of Set 9 | tazacorte
# Processing Record 11 of Set 9 | sovetskiy
# Processing Record 12 of Set 9 | imbituba
# Processing Record 13 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 14 of Set 9 | lompoc
# Processing Record 15 of Set 9 | majalgaon
# Processing Record 16 of Set 9 | tevragh zeina
# City not found. Skipping...
# Processing Record 17 of Set 9 | buala
# Processing Record 18 of Set 9 | yanam
# Processing Record 19 of Set 9 | brisas de zicatela
# Processing Record 20 of Set 9 | twin falls
# Processing Record 21 of Set 9 | baume-les-dames
# Processing Record 22 of Set 9 | st. john's
# Processing Record 23 of Set 9 | bac lieu
# Processing Record 24 of Set 9 | sitka
# Processing Record 25 of Set 9 | preobrazheniye
# Processing Record 26 of Set 9 | gibsons
# Processing Record 27 of Set 9 | asau village
# City not found. Skipping...
# Processing Record 28 of Set 9 | khandyga
# Processing Record 29 of Set 9 | usogorsk
# Processing Record 30 of Set 9 | helong
# Processing Record 31 of Set 9 | boyolangu
# Processing Record 32 of Set 9 | saint-pierre
# Processing Record 33 of Set 9 | saint-philippe
# Processing Record 34 of Set 9 | tobruk
# Processing Record 35 of Set 9 | amboasary
# Processing Record 36 of Set 9 | ladario
# Processing Record 37 of Set 9 | tanjungagung
# Processing Record 38 of Set 9 | minas de matahambre
# City not found. Skipping...
# Processing Record 39 of Set 9 | rechka-vydrino
# Processing Record 40 of Set 9 | ar rass
# Processing Record 41 of Set 9 | sylvester
# Processing Record 42 of Set 9 | ta`u
# Processing Record 43 of Set 9 | ust-tsilma
# Processing Record 44 of Set 9 | kalmunai
# Processing Record 45 of Set 9 | nemuro
# Processing Record 46 of Set 9 | salair
# Processing Record 47 of Set 9 | ust'-kut
# Processing Record 48 of Set 9 | san pedro pochutla
# Processing Record 49 of Set 9 | bastad
# Processing Record 50 of Set 9 | chokwe
# Processing Record 1 of Set 10 | isla del bosque
# Processing Record 2 of Set 10 | hobyo
# Processing Record 3 of Set 10 | narasapur
# Processing Record 4 of Set 10 | polyarnyye zori
# Processing Record 5 of Set 10 | ialibu
# Processing Record 6 of Set 10 | duncan town
# City not found. Skipping...
# Processing Record 7 of Set 10 | severo-yeniseyskiy
# Processing Record 8 of Set 10 | kindu
# Processing Record 9 of Set 10 | brockport
# Processing Record 10 of Set 10 | xinyuan
# Processing Record 11 of Set 10 | ermoupolis
# Processing Record 12 of Set 10 | al bawiti
# Processing Record 13 of Set 10 | nizhneangarsk
# Processing Record 14 of Set 10 | shiojiri
# Processing Record 15 of Set 10 | kilindoni
# Processing Record 16 of Set 10 | slave lake
# Processing Record 17 of Set 10 | machico
# Processing Record 18 of Set 10 | novyye burasy
# Processing Record 19 of Set 10 | kiunga
# Processing Record 20 of Set 10 | sankt johann in tirol
# Processing Record 21 of Set 10 | dampit
# Processing Record 22 of Set 10 | la peca
# Processing Record 23 of Set 10 | madinat sittah uktubar
# Processing Record 24 of Set 10 | dubovka
# Processing Record 25 of Set 10 | bordighera
# Processing Record 26 of Set 10 | katsuura
# Processing Record 27 of Set 10 | bridgewater
# Processing Record 28 of Set 10 | singkawang
# Processing Record 29 of Set 10 | kuanda
# Processing Record 30 of Set 10 | ixtapa
# Processing Record 31 of Set 10 | nagqu
# Processing Record 32 of Set 10 | la ceiba
# Processing Record 33 of Set 10 | al 'aziziyah
# Processing Record 34 of Set 10 | fisterra
# Processing Record 35 of Set 10 | nezhinka
# Processing Record 36 of Set 10 | mugia
# Processing Record 37 of Set 10 | enriquillo
# Processing Record 38 of Set 10 | onguday
# Processing Record 39 of Set 10 | suihua
# Processing Record 40 of Set 10 | colonia
# Processing Record 41 of Set 10 | lazaro cardenas
# Processing Record 42 of Set 10 | karaton
# Processing Record 43 of Set 10 | okhotsk
# Processing Record 44 of Set 10 | sioux city
# Processing Record 45 of Set 10 | gajuwaka
# Processing Record 46 of Set 10 | shannon
# Processing Record 47 of Set 10 | tilisarao
# Processing Record 48 of Set 10 | pingxiang
# Processing Record 49 of Set 10 | alcarras
# Processing Record 50 of Set 10 | upington
# Processing Record 1 of Set 11 | anatuya
# Processing Record 2 of Set 11 | ostersund
# Processing Record 3 of Set 11 | colchani
# Processing Record 4 of Set 11 | shtime
# Processing Record 5 of Set 11 | amursk
# Processing Record 6 of Set 11 | sydney
# Processing Record 7 of Set 11 | aflou
# Processing Record 8 of Set 11 | lakshettipet
# Processing Record 9 of Set 11 | sandy
# Processing Record 10 of Set 11 | sapatgram
# Processing Record 11 of Set 11 | cadale
# Processing Record 12 of Set 11 | swanage
# Processing Record 13 of Set 11 | margate
# Processing Record 14 of Set 11 | yuzhno-kurilsk
# Processing Record 15 of Set 11 | prince rupert
# Processing Record 16 of Set 11 | birobidzhan
# Processing Record 17 of Set 11 | okazaki
# Processing Record 18 of Set 11 | kakonko
# Processing Record 19 of Set 11 | mejit
# Processing Record 20 of Set 11 | tralee
# Processing Record 21 of Set 11 | vylkove
# Processing Record 22 of Set 11 | tosontsengel
# Processing Record 23 of Set 11 | cockburn town
# Processing Record 24 of Set 11 | haparanda
# Processing Record 25 of Set 11 | merouana
# Processing Record 26 of Set 11 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 11 | charters towers
# Processing Record 28 of Set 11 | mineiros
# Processing Record 29 of Set 11 | portland
# Processing Record 30 of Set 11 | bestobe
# Processing Record 31 of Set 11 | as salt
# Processing Record 32 of Set 11 | katsuren-haebaru
# Processing Record 33 of Set 11 | nantucket
# Processing Record 34 of Set 11 | rio grande
# Processing Record 35 of Set 11 | kruisfontein
# Processing Record 36 of Set 11 | arinos
# Processing Record 37 of Set 11 | hermantown
# Processing Record 38 of Set 11 | elmendorf air force base
# City not found. Skipping...
# Processing Record 39 of Set 11 | dombarovskiy
# Processing Record 40 of Set 11 | gorontalo
# Processing Record 41 of Set 11 | swellendam
# Processing Record 42 of Set 11 | villa de soto
# Processing Record 43 of Set 11 | talara
# Processing Record 44 of Set 11 | ceerigaabo
# Processing Record 45 of Set 11 | tamarin
# Processing Record 46 of Set 11 | tanumah
# Processing Record 47 of Set 11 | wuxue
# Processing Record 48 of Set 11 | lively
# Processing Record 49 of Set 11 | la paz
# Processing Record 50 of Set 11 | porto novo
# Processing Record 1 of Set 12 | pyriatyn
# Processing Record 2 of Set 12 | valenca do piaui
# Processing Record 3 of Set 12 | son ferrer
# City not found. Skipping...
# Processing Record 4 of Set 12 | fianarantsoa
# Processing Record 5 of Set 12 | sinabang
# Processing Record 6 of Set 12 | vilhena
# Processing Record 7 of Set 12 | gilmer
# Processing Record 8 of Set 12 | la'ie
# Processing Record 9 of Set 12 | ahau
# City not found. Skipping...
# Processing Record 10 of Set 12 | am djarass
# City not found. Skipping...
# Processing Record 11 of Set 12 | bambui
# Processing Record 12 of Set 12 | smithers
# Processing Record 13 of Set 12 | dryden
# Processing Record 14 of Set 12 | domodossola
# Processing Record 15 of Set 12 | nyurba
# Processing Record 16 of Set 12 | ibotirama
# Processing Record 17 of Set 12 | sona
# Processing Record 18 of Set 12 | roma
# Processing Record 19 of Set 12 | manturovo
# Processing Record 20 of Set 12 | krasnoturansk
# Processing Record 21 of Set 12 | raymondville
# Processing Record 22 of Set 12 | chizhou
# Processing Record 23 of Set 12 | salinopolis
# Processing Record 24 of Set 12 | zilair
# Processing Record 25 of Set 12 | bouafle
# Processing Record 26 of Set 12 | tateyama
# Processing Record 27 of Set 12 | hadithah
# Processing Record 28 of Set 12 | acarau
# Processing Record 29 of Set 12 | malango
# Processing Record 30 of Set 12 | sao gabriel da cachoeira
# Processing Record 31 of Set 12 | necochea
# Processing Record 32 of Set 12 | saryozek
# Processing Record 33 of Set 12 | hanko
# Processing Record 34 of Set 12 | jijiga
# Processing Record 35 of Set 12 | monduli
# Processing Record 36 of Set 12 | north bend
# Processing Record 37 of Set 12 | mitu
# Processing Record 38 of Set 12 | blagodatnoye
# Processing Record 39 of Set 12 | san antonio de pale
# Processing Record 40 of Set 12 | argo
# Processing Record 41 of Set 12 | puerto princesa
# Processing Record 42 of Set 12 | nanuque
# Processing Record 43 of Set 12 | el colorado
# Processing Record 44 of Set 12 | bilmak
# Processing Record 45 of Set 12 | ksar el boukhari
# Processing Record 46 of Set 12 | sisimiut
# Processing Record 47 of Set 12 | huacho
# Processing Record 48 of Set 12 | igarka
# Processing Record 49 of Set 12 | kenai
# Processing Record 50 of Set 12 | jianguang
# Processing Record 1 of Set 13 | homestead meadows north
# Processing Record 2 of Set 13 | liaozhong
# Processing Record 3 of Set 13 | kiamba
# Processing Record 4 of Set 13 | marti
# Processing Record 5 of Set 13 | kataragama
# City not found. Skipping...
# Processing Record 6 of Set 13 | tulcingo de valle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the city data to a DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       invercargill -46.4000  168.3500     57.81        77         100
# 1        yellowknife  62.4560 -114.3525     63.12        34          20
# 2  port-aux-francais -49.3500   70.2167     44.29        97          99
# 3           bengkulu  -3.8004  102.2655     80.69        75          59
# 4          adamstown -25.0660 -130.1015     69.96        54          96
#
#    Wind Speed Country                 Date
# 0        5.68      NZ  2023-05-28 22:02:29
# 1       15.01      CA  2023-05-28 21:56:29
# 2       11.61      TF  2023-05-28 22:02:30
# 3        1.72      ID  2023-05-28 22:02:31
# 4       14.61      PN  2023-05-28 22:02:31

# %%
# Export the City_Data to a CSV file in the output_data folder
city_data_df.to_csv("output_data/city_data.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/city_data.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             invercargill -46.4000  168.3500     57.81        77         100
# 1              yellowknife  62.4560 -114.3525     63.12        34          20
# 2        port-aux-francais -49.3500   70.2167     44.29        97          99
# 3                 bengkulu  -3.8004  102.2655     80.69        75          59
# 4                adamstown -25.0660 -130.1015     69.96        54          96
#
#          Wind Speed Country                 Date
# City_ID
# 0              5.68      NZ  2023-05-28 22:02:29
# 1             15.01      CA  2023-05-28 21:56:29
# 2             11.61      TF  2023-05-28 22:02:30
# 3              1.72      ID  2023-05-28 22:02:31
# 4             14.61      PN  2023-05-28 22:02:31

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Convert Max Temperature from Fahrenheit to Celsius
city_data_df["Max Temp (C)"] = (city_data_df["Max Temp"] - 32) * 5/9

# Get the date from the DataFrame
date = city_data_df["Date"].iloc[0]

# Build scatter plot for Latitude vs. Max Temperature in Celsius
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp (C)"], edgecolor="black")

# Set the title and labels
plt.title("City Latitude vs. Max Temperature (Celsius) - " + date)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (Celsius)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black")

# Set the title and labels
plt.title("City Latitude vs. Humidity - " + city_data_df["Date"].iloc[0])
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black")

# Set the title and labels
plt.title("City Latitude vs. Cloudiness - " + city_data_df["Date"].iloc[0])
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show the plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black")

# Set the title and labels
plt.title(f"City Latitude vs. Wind Speed ({date})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

# Set the grid lines
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show the plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, x_label, y_label, title, file_name):
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line
    regress_values = x_values * slope + intercept
    
    # Create scatter plot and regression line
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    
    # Annotate the equation of the line on the plot
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.annotate(equation, (min(x_values), min(y_values)), fontsize=12, color="red")
    
    # Set the title and labels
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    
    # Save the plot
    plt.savefig(file_name)
    
    # Show the plot
    plt.show()

# %%
# Filter the city data for Northern Hemisphere (latitude >= 0)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1             yellowknife  62.4560 -114.3525     63.12        34          20
# 5                   galle   6.0367   80.2170     82.53        81          59
# 8                midvagur  62.0511   -7.1939     49.03        93         100
# 9        kill devil hills  36.0307  -75.6760     70.99        95         100
# 10                   tura  25.5198   90.2201     84.92        53           0
#
#          Wind Speed Country                 Date  Max Temp (C)
# City_ID
# 1             15.01      CA  2023-05-28 21:56:29     17.288889
# 5              8.46      LK  2023-05-28 22:02:32     28.072222
# 8             24.16      FO  2023-05-28 22:02:35      9.461111
# 9              6.91      US  2023-05-28 22:02:35     21.661111
# 10             0.40      IN  2023-05-28 22:02:36     29.400000

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)

# Filter the city data for Southern Hemisphere (latitude < 0)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             invercargill -46.4000  168.3500     57.81        77         100
# 2        port-aux-francais -49.3500   70.2167     44.29        97          99
# 3                 bengkulu  -3.8004  102.2655     80.69        75          59
# 4                adamstown -25.0660 -130.1015     69.96        54          96
# 6                 waitangi -43.9535 -176.5597     57.81        80          95
#
#          Wind Speed Country                 Date  Max Temp (C)
# City_ID
# 0              5.68      NZ  2023-05-28 22:02:29     14.338889
# 2             11.61      TF  2023-05-28 22:02:30      6.827778
# 3              1.72      ID  2023-05-28 22:02:31     27.050000
# 4             14.61      PN  2023-05-28 22:02:31     21.088889
# 6              5.99      NZ  2023-05-28 22:02:33     14.338889

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, xlabel, ylabel, coordinates):
    # Convert temperature from Fahrenheit to Celsius
    y_values = (y_values - 32) * 5/9
    
    # Perform linear regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    
    # Calculate the regression line
    regress_values = x_values * slope + intercept
    
    # Create the scatter plot
    plt.scatter(x_values, y_values)
    
    # Plot the regression line
    plt.plot(x_values, regress_values, color='red')
    
    # Annotate the equation of the line on the plot
    equation = f"y = {round(slope, 2)}x + {round(intercept, 2)}"
    plt.annotate(equation, coordinates, fontsize=15, color='red')
    
    # Add titles and labels
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # Print the r-squared value
    print(f"The r-squared is: {round(rvalue**2, 2)}")
    
    # Show the plot
    plt.show()

# Perform linear regression on Northern Hemisphere temperature vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Temperature vs. Latitude",
                       "Latitude", "Max Temperature (°C)", (0, -30))
# Out:
# The r-squared is: 0.68

# %%
# Perform linear regression on Southern Hemisphere temperature vs latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Temperature vs. Latitude",
                       "Latitude", "Max Temperature (°C)", (-50, 40))
# Out:
# The r-squared is: 0.59

# %% [markdown]
# Based on the linear regression analysis for the Cloudiness vs. Latitude in the Northern Hemisphere, we can observe that there is no strong linear relationship between these two variables. The regression line has a small positive slope, indicating a slight increase in cloudiness as we move towards higher latitudes in the Northern Hemisphere. However, the scatter plot of the data points shows a considerable amount of dispersion, suggesting that latitude alone may not be a strong predictor of cloudiness.
#
# The low R-squared value further supports this observation, indicating that only a small proportion of the variance in cloudiness can be explained by latitude in the Northern Hemisphere. Other factors such as local weather patterns, geography, and atmospheric conditions are likely to have a more significant influence on cloudiness levels.
#
# Therefore, while there is a weak positive trend between cloudiness and latitude in the Northern Hemisphere, it is important to consider additional factors and variables to gain a more comprehensive understanding of the cloudiness patterns in this region.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere humidity vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Humidity vs. Latitude",
                       "Latitude", "Humidity (%)", (10, 40))

# %%
# Perform linear regression on Northern Hemisphere temperature vs humidity
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Temperature vs. Humidity",
                       "Latitude", "Humidity (%)", (10, 40))

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere humidity vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Humidity vs. Latitude",
                       "Latitude", "Humidity (%)", (40, 10))
# Out:
# The r-squared is: 0.01

# %%
# Perform linear regression on Southern Hemisphere humidity vs latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Humidity vs. Latitude",
                       "Latitude", "Humidity (%)", (-50, 20))
# Out:
# The r-squared is: 0.02

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Perform linear regression on Northern Hemisphere wind speed vs latitude
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Linear Regression: Northern Hemisphere - Wind Speed vs. Latitude",
                       "Latitude", "Wind Speed (mph)", (40, 25))
# Out:
# The r-squared is: 0.0

# %%
# Perform linear regression on Southern Hemisphere wind speed vs latitude
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Linear Regression: Southern Hemisphere - Wind Speed vs. Latitude",
                       "Latitude", "Wind Speed (mph)", (-50, 20))
# Out:
# The r-squared is: 0.04

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
